# %% [markdown]
# # far and mid

# %%
recs = ["A", "B", "C", "D"]
filts = ["near"]

for R in recs:
    for F in filts:
        if F=="near":
            # filtering near, so name should be Far only
            N = "FAR_ONLY"
        if F=="far":
            # filtering far, so name should be Near only
            N = "NEAR_ONLY"
        
        p1 = f"F:/visceral_v1/Recording{R}/raw_videos/" # input path
        p2 = f"H:/code_bal" # output path  f"H:/code_bal/VISCERAL_REC_{R}/"
        p3 = f"camera_movement_VIS_REC_{R}_({N})" # plot name
        p4 = f"\"aria, ego, iphone, canon, {F}\"" # blacklist
        p5 = f"START-00:10:00" # window
        
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
        print("\n")
        
        # !python run.py --input-video-path {p1} --output_path {p2} --plot_name {p3} --name_blacklist {p4} --static_window {p5} --n_main_steps 32 --n_init_steps 8

# %%
recs = ["A", "B", "C"]
filts = ["mid", "far"]

for R in recs:
    for F in filts:
        if F=="mid":
            N = "FAR_ONLY"
        if F=="far":
            # filtering far, so name should be Near only
            N = "MID_ONLY"
            
        p1 = f"E:/THA_v2/recording_{R}/raw_videos/" # input path
        p2 = f"H:/code_bal" # output path  f"H:/code_bal/VISCERAL_REC_{R}/"
        p3 = f"camera_movement_THA_REC_{R}_({N})" # plot name
        p4 = f"\"aria, ego, iphone, canon, near, {F}\"" # blacklist
        p5 = f"START-00:10:00" # window
        
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
        print("\n")
        
        # !python run.py --input-video-path {p1} --output_path {p2} --plot_name {p3} --name_blacklist {p4} --static_window {p5} --n_main_steps 32 --n_init_steps 8

# %% [markdown]
# # near only

# %%
recs = ["A", "B", "C", "D"]
filts = [" "]

for R in recs:
    for F in filts:
        
        p1 = f"F:/visceral_v1/Recording{R}/raw_videos/" # input path
        p2 = f"H:/code_bal" # output path  f"H:/code_bal/VISCERAL_REC_{R}/"
        p3 = f"camera_movement_VIS_REC_{R}_(NEAR_ONLY)" # plot name
        p4 = f"\"aria, ego, iphone, canon, far, mid\"" # blacklist
        p5 = f"START-00:10:00" # window
        
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
        print("\n")
        
        # !python run.py --input-video-path {p1} --output_path {p2} --plot_name {p3} --name_blacklist {p4} --static_window {p5} --n_main_steps 32 --n_init_steps 8

# %%
recs = ["A", "B", "C"]
filts = [" "]

for R in recs:
    for F in filts:
            
        p1 = f"E:/THA_v2/recording_{R}/raw_videos/" # input path
        p2 = f"H:/code_bal" # output path  f"H:/code_bal/VISCERAL_REC_{R}/"
        p3 = f"camera_movement_THA_REC_{R}_(NEAR_ONLY)" # plot name
        p4 = f"\"aria, ego, iphone, canon, far, mid\"" # blacklist
        p5 = f"START-00:10:00" # window
        
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
        print("\n")
        
        # !python run.py --input-video-path {p1} --output_path {p2} --plot_name {p3} --name_blacklist {p4} --static_window {p5} --n_main_steps 32 --n_init_steps 8
